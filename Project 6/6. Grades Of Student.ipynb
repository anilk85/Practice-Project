# %% [markdown]
# Grades of Student Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading Dataset:

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv')

# %%
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %% [markdown]
# This Dataframe columns are a categorical data, It convert categorical to digit value..

# %% [markdown]
# import Label Encoder from sklearn for converting the categorical to digit data..

# %%
# Use the Encoding technique for convert categorical data to digit data..

from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

# %%
for i in df.columns:
    df[i] = LE.fit_transform(df[i])

# %%
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
# it shows the 5 rows..

df.head()
# Out:
#    Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0         0       5      10       8          6       8      10       9
# 1         1       0       9      10          9       5       6       9
# 2         2       0       3       0          5       4       0       5
# 3         3       9       7      10          9       9       2      10
# 4         4       2       2       2          4       0       0       2
#
#    EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# 0       8       5  ...       8       8       8       8       2       0
# 1       0      10  ...      10       9       6       9       2       5
# 2       4       2  ...       3       3       0       6       0       0
# 3       8       9  ...      10       6      10       8       5       3
# 4       4       0  ...       5       4       4       5       2       0
#
#    CS-419  CS-423  CS-412  CGPA
# 0       8       3       2    72
# 1       6       6       3    48
# ...

# %%
# it shows the last 5 rows...

df.tail()
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# 566       2       1  ...       2       2       0       0       0       4
# 567       2       0  ...       4       4       0       0       2       3
# 568       0       0  ...       2       3       0       4       0       6
# 569       8       5  ...       9       3       3       8       9       6
# 570       7       6  ...       7       6       5       9      11       8
#
#      CS-419  CS-423  CS-412  CGPA
# 566       4       3       0   459
# ...

# %%
# Dimension of my dataset..

df.shape
# Out:
# (571, 43)

# %% [markdown]
# It observed 571 rows and 43 columns including targhet columns of the dataset

# %% [markdown]
# checking missing value (null value) of my DataFrame

# %%
# np.nan, none, Nan, others...

df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# it observed there is no missing value of the dataset

# %%
# Checking the datatypes of coloumns:

df.dtypes
# Out:
# Seat No.     int32
# PH-121       int32
# HS-101       int32
# CY-105       int32
# HS-105/12    int32
# MT-111       int32
# CS-105       int32
# CS-106       int32
# EL-102       int32
# EE-119       int32
# ME-107       int32
# CS-107       int32
# HS-205/20    int32
# MT-222       int32
# EE-222       int32
# MT-224       int32
# CS-210       int32
# CS-211       int32
# CS-203       int32
# CS-214       int32
# EE-217       int32
# CS-212       int32
# CS-215       int32
# MT-331       int32
# EF-303       int32
# HS-304       int32
# CS-301       int32
# CS-302       int32
# TC-383       int32
# MT-442       int32
# EL-332       int32
# CS-318       int32
# CS-306       int32
# CS-312       int32
# CS-317       int32
# CS-403       int32
# CS-421       int32
# CS-406       int32
# CS-414       int32
# CS-419       int32
# CS-423       int32
# CS-412       int32
# CGPA         int64
# dtype: object

# %% [markdown]
# Data Analysis:

# %%
df_visualization_nominal = df[['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
       'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
       'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
       'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
       'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
       'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
       'CS-412', 'CGPA']].copy()

# %%
df_visualization_nominal.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %% [markdown]
# Data Visualization:

# %%
import seaborn as sns

# %%
ax = sns.countplot(x = 'Seat No.', data = df_visualization_nominal)
print(df_visualization_nominal['Seat No.'].value_counts())
# Out:
# 0      1
# 383    1
# 377    1
# 378    1
# 379    1
#       ..
# 184    1
# 183    1
# 182    1
# 181    1
# 570    1
# Name: Seat No., Length: 571, dtype: int64

# %%
ax = sns.countplot(x = 'PH-121', data = df_visualization_nominal)
print(df_visualization_nominal['PH-121'].value_counts())
# Out:
# 2     112
# 0     111
# 4      61
# 3      57
# 5      56
# 9      44
# 6      33
# 7      31
# 10     22
# 1      22
# 8      19
# 12      2
# 11      1
# Name: PH-121, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 112 students for PH-121

# %%
ax = sns.countplot(x = 'HS-101', data = df_visualization_nominal)
print(df_visualization_nominal['HS-101'].value_counts())
# Out:
# 2     82
# 5     78
# 6     68
# 3     63
# 4     59
# 8     50
# 7     47
# 9     45
# 0     38
# 10    36
# 1      4
# 11     1
# Name: HS-101, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 82 students for HS-101

# %%
ax = sns.countplot(x = 'CY-105', data = df_visualization_nominal)
print(df_visualization_nominal['CY-105'].value_counts())
# Out:
# 0     177
# 2     120
# 4      50
# 3      49
# 5      42
# 9      31
# 1      31
# 6      19
# 7      17
# 8      16
# 10     14
# 12      3
# 13      1
# 11      1
# Name: CY-105, dtype: int64

# %% [markdown]
# Here 0 is enocded value of a grade! And that is scored by 177 students for CY-105

# %%
ax = sns.countplot(x = 'HS-105/12', data = df_visualization_nominal)
print(df_visualization_nominal['HS-105/12'].value_counts())
# Out:
# 0     96
# 2     75
# 4     70
# 3     57
# 9     45
# 6     41
# 5     40
# 7     39
# 8     36
# 10    34
# 1     34
# 12     2
# 13     1
# 11     1
# Name: HS-105/12, dtype: int64

# %% [markdown]
# Here 0 is enocded value of a grade! And that is scored by 96 students for HS-105/12

# %%
ax = sns.countplot(x = 'MT-111', data = df_visualization_nominal)
print(df_visualization_nominal['MT-111'].value_counts())
# Out:
# 2     105
# 0     100
# 5      70
# 4      62
# 3      55
# 8      39
# 7      33
# 6      30
# 9      26
# 1      23
# 10     21
# 12      3
# 13      2
# 11      2
# Name: MT-111, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 105 students for MT-111

# %%
ax = sns.countplot(x = 'CS-105', data = df_visualization_nominal)
print(df_visualization_nominal['CS-105'].value_counts())
# Out:
# 0     151
# 2     134
# 4      60
# 3      51
# 1      43
# 5      38
# 7      23
# 6      22
# 8      22
# 10     15
# 9      12
# Name: CS-105, dtype: int64

# %% [markdown]
# Here 0 is enocded value of a grade! And that is scored by 151 students for CS-105

# %%
ax = sns.countplot(x = 'CS-106', data = df_visualization_nominal)
print(df_visualization_nominal['CS-106'].value_counts())
# Out:
# 2     116
# 4     101
# 3      96
# 0      56
# 5      54
# 7      41
# 10     29
# 8      27
# 9      24
# 6      18
# 1       4
# 13      2
# 12      2
# 11      1
# Name: CS-106, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 116 students for CS-106

# %%
ax = sns.countplot(x = 'EL-102', data = df_visualization_nominal)
print(df_visualization_nominal['EL-102'].value_counts())
# Out:
# 2     105
# 0      92
# 4      69
# 3      59
# 5      53
# 9      38
# 7      35
# 8      32
# 6      30
# 1      29
# 10     23
# 12      3
# 13      2
# 11      1
# Name: EL-102, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 105 students for EL-102

# %%
ax = sns.countplot(x = 'EE-119', data = df_visualization_nominal)
print(df_visualization_nominal['EE-119'].value_counts())
# Out:
# 2     137
# 4      83
# 3      77
# 0      68
# 5      48
# 6      48
# 7      38
# 10     26
# 8      26
# 9      11
# 1       6
# 12      2
# 11      1
# Name: EE-119, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 137 students for EE-119

# %%
ax = sns.countplot(x = 'ME-107', data = df_visualization_nominal)
print(df_visualization_nominal['ME-107'].value_counts())
# Out:
# 2     79
# 0     77
# 4     68
# 9     56
# 5     56
# 3     50
# 6     49
# 8     48
# 7     37
# 10    37
# 1      8
# 12     2
# 13     2
# 11     2
# Name: ME-107, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 37 students for ME-107

# %%
ax = sns.countplot(x = 'CS-107', data = df_visualization_nominal)
print(df_visualization_nominal['CS-107'].value_counts())
# Out:
# 0     105
# 2      81
# 4      57
# 3      55
# 8      49
# 5      43
# 1      42
# 9      38
# 7      34
# 10     31
# 6      30
# 14      2
# 13      2
# 12      1
# 11      1
# Name: CS-107, dtype: int64

# %% [markdown]
# Here 0 is enocded value of a grade! And that is scored by 105 students for CS-107

# %%
ax = sns.countplot(x = 'HS-205/20', data = df_visualization_nominal)
print(df_visualization_nominal['HS-205/20'].value_counts())
# Out:
# 2     150
# 0     118
# 3      97
# 4      89
# 5      36
# 7      33
# 6      15
# 8      11
# 10      9
# 13      5
# 9       3
# 1       2
# 11      2
# 12      1
# Name: HS-205/20, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 150 students for HS-205/20

# %%
ax = sns.countplot(x = 'MT-222', data = df_visualization_nominal)
print(df_visualization_nominal['MT-222'].value_counts())
# Out:
# 2     86
# 0     80
# 9     66
# 3     61
# 5     52
# 10    46
# 6     43
# 4     42
# 7     39
# 8     30
# 1     16
# 14     5
# 11     3
# 13     1
# 12     1
# Name: MT-222, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 86 students for MT-222

# %%
ax = sns.countplot(x = 'EE-222', data = df_visualization_nominal)
print(df_visualization_nominal['EE-222'].value_counts())
# Out:
# 0     122
# 2     121
# 4      65
# 3      53
# 6      39
# 5      35
# 1      32
# 7      29
# 9      25
# 10     21
# 8      16
# 13      7
# 11      4
# 12      2
# Name: EE-222, dtype: int64

# %% [markdown]
# Here 0 is enocded value of a grade! And that is scored by 122 students for EE-222

# %%
ax = sns.countplot(x = 'MT-224', data = df_visualization_nominal)
print(df_visualization_nominal['MT-224'].value_counts())
# Out:
# 2     120
# 0      80
# 4      65
# 3      57
# 5      49
# 8      43
# 7      39
# 10     37
# 9      31
# 6      30
# 1      10
# 14      7
# 13      1
# 12      1
# 11      1
# Name: MT-224, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 120 students for MT-224

# %%
ax = sns.countplot(x = 'CS-210', data = df_visualization_nominal)
print(df_visualization_nominal['CS-210'].value_counts())
# Out:
# 2     133
# 0     101
# 4      84
# 3      59
# 5      58
# 6      30
# 7      27
# 8      24
# 10     21
# 9      12
# 1      12
# 14      7
# 13      1
# 12      1
# 11      1
# Name: CS-210, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 133 students for CS-210

# %%
ax = sns.countplot(x = 'CS-211', data = df_visualization_nominal)
print(df_visualization_nominal['CS-211'].value_counts())
# Out:
# 2     68
# 0     67
# 5     60
# 10    56
# 4     56
# 3     56
# 7     55
# 8     50
# 6     39
# 9     33
# 1     21
# 14     5
# 11     3
# 13     1
# 12     1
# Name: CS-211, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 68 students for CS-211

# %%
ax = sns.countplot(x = 'CS-203', data = df_visualization_nominal)
print(df_visualization_nominal['CS-203'].value_counts())
# Out:
# 2     88
# 0     81
# 3     66
# 7     62
# 4     59
# 5     53
# 10    39
# 6     35
# 8     35
# 9     30
# 1     15
# 13     5
# 11     2
# 12     1
# Name: CS-203, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 88 students for CS-203

# %%
ax = sns.countplot(x = 'CS-214', data = df_visualization_nominal)
print(df_visualization_nominal['CS-214'].value_counts())
# Out:
# 6     76
# 2     73
# 3     63
# 8     57
# 5     56
# 0     56
# 10    47
# 7     46
# 4     45
# 9     31
# 1     12
# 13     6
# 11     2
# 12     1
# Name: CS-214, dtype: int64

# %% [markdown]
# Here 6 is enocded value of a grade! And that is scored by 76 students for CS-214

# %%
ax = sns.countplot(x = 'EE-217', data = df_visualization_nominal)
print(df_visualization_nominal['EE-217'].value_counts())
# Out:
# 2     137
# 0      97
# 4      70
# 3      63
# 5      57
# 6      36
# 7      29
# 1      22
# 8      20
# 10     19
# 9      12
# 13      6
# 11      2
# 12      1
# Name: EE-217, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 137 students for EE-217

# %%
ax = sns.countplot(x = 'CS-212', data = df_visualization_nominal)
print(df_visualization_nominal['CS-212'].value_counts())
# Out:
# 2     101
# 4      86
# 3      81
# 5      65
# 6      44
# 0      43
# 10     36
# 7      35
# 8      35
# 9      33
# 12      6
# 1       4
# 11      2
# Name: CS-212, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 101 students for CS-212

# %%
ax = sns.countplot(x = 'CS-215', data = df_visualization_nominal)
print(df_visualization_nominal['CS-215'].value_counts())
# Out:
# 2     79
# 0     68
# 3     64
# 5     59
# 7     50
# 4     50
# 6     48
# 8     47
# 9     42
# 10    38
# 1     17
# 14     6
# 13     1
# 12     1
# 11     1
# Name: CS-215, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 79 students for CS-215

# %%
ax = sns.countplot(x = 'MT-331', data = df_visualization_nominal)
print(df_visualization_nominal['MT-331'].value_counts())
# Out:
# 0     118
# 2     103
# 4      64
# 3      57
# 5      46
# 8      32
# 10     31
# 1      30
# 6      28
# 7      27
# 9      22
# 12      9
# 11      4
# Name: MT-331, dtype: int64

# %% [markdown]
# Here 0 is enocded value of a grade! And that is scored by 118 students for MT-331

# %%
ax = sns.countplot(x = 'EF-303', data = df_visualization_nominal)
print(df_visualization_nominal['EF-303'].value_counts())
# Out:
# 2     112
# 4      92
# 5      61
# 3      59
# 6      58
# 7      56
# 9      49
# 1      38
# 8      19
# 0      14
# 12     10
# 10      2
# 11      1
# Name: EF-303, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 112 students for EF-303

# %%
ax = sns.countplot(x = 'HS-304', data = df_visualization_nominal)
print(df_visualization_nominal['HS-304'].value_counts())
# Out:
# 2     128
# 3      72
# 5      70
# 4      66
# 6      58
# 7      53
# 8      33
# 0      28
# 9      20
# 10     19
# 14     10
# 11      6
# 1       4
# 13      2
# 12      2
# Name: HS-304, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 128 students for HS-304

# %%
ax = sns.countplot(x = 'CS-301', data = df_visualization_nominal)
print(df_visualization_nominal['CS-301'].value_counts())
# Out:
# 2     108
# 4      74
# 3      71
# 0      66
# 5      60
# 6      41
# 7      37
# 8      36
# 9      29
# 10     29
# 12     10
# 1       9
# 11      1
# Name: CS-301, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 108 students for CS-301

# %%
ax = sns.countplot(x = 'CS-302', data = df_visualization_nominal)
print(df_visualization_nominal['CS-302'].value_counts())
# Out:
# 2     113
# 3     102
# 0      86
# 4      81
# 5      60
# 7      32
# 6      28
# 9      21
# 8      19
# 10     10
# 11     10
# 1       9
# Name: CS-302, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 118 students for CS-302

# %%
ax = sns.countplot(x = 'TC-383', data = df_visualization_nominal)
print(df_visualization_nominal['TC-383'].value_counts())
# Out:
# 0     105
# 2      73
# 4      68
# 3      59
# 7      44
# 10     44
# 8      42
# 6      42
# 5      40
# 1      23
# 9      20
# 12     10
# 11      1
# Name: TC-383, dtype: int64

# %% [markdown]
# Here 0 is enocded value of a grade! And that is scored by 105 students for TC-383

# %%
ax = sns.countplot(x = 'MT-442', data = df_visualization_nominal)
print(df_visualization_nominal['MT-442'].value_counts())
# Out:
# 2     140
# 0     130
# 4      65
# 3      47
# 1      39
# 5      30
# 8      28
# 7      24
# 6      24
# 9      20
# 10     13
# 12     10
# 11      1
# Name: MT-442, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 140 students for MT-442

# %%
ax = sns.countplot(x = 'EL-332', data = df_visualization_nominal)
print(df_visualization_nominal['EL-332'].value_counts())
# Out:
# 2     96
# 0     76
# 4     68
# 3     67
# 5     62
# 6     49
# 7     38
# 8     32
# 10    22
# 9     22
# 1     20
# 13     9
# 11     9
# 12     1
# Name: EL-332, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 96 students for EL-332

# %%
ax = sns.countplot(x = 'CS-318', data = df_visualization_nominal)
print(df_visualization_nominal['CS-318'].value_counts())
# Out:
# 2     89
# 5     69
# 3     68
# 4     65
# 6     53
# 7     49
# 0     42
# 8     40
# 9     36
# 10    29
# 11    10
# 14     9
# 1      6
# 13     5
# 12     1
# Name: CS-318, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 89 students for CS-318

# %%
ax = sns.countplot(x = 'CS-306', data = df_visualization_nominal)
print(df_visualization_nominal['CS-306'].value_counts())
# Out:
# 2     120
# 4      75
# 0      74
# 5      64
# 3      53
# 8      40
# 6      37
# 7      36
# 9      31
# 10     18
# 1      10
# 13      9
# 11      3
# 12      1
# Name: CS-306, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 120 students for CS-306

# %%
ax = sns.countplot(x = 'CS-312', data = df_visualization_nominal)
print(df_visualization_nominal['CS-312'].value_counts())
# Out:
# 1     93
# 0     86
# 2     63
# 10    52
# 6     48
# 8     44
# 4     42
# 3     37
# 7     37
# 5     36
# 9     19
# 14    10
# 11     2
# 12     1
# 13     1
# Name: CS-312, dtype: int64

# %% [markdown]
# Here 1 is enocded value of a grade! And that is scored by 93 students for CS-312

# %%
ax = sns.countplot(x = 'CS-317', data = df_visualization_nominal)
print(df_visualization_nominal['CS-317'].value_counts())
# Out:
# 5     79
# 3     75
# 6     70
# 2     66
# 4     58
# 7     57
# 0     47
# 8     41
# 10    34
# 9     16
# 12    12
# 1      9
# 11     7
# Name: CS-317, dtype: int64

# %% [markdown]
# Here 5 is enocded value of a grade! And that is scored by 79 students for CS-317

# %%
ax = sns.countplot(x = 'CS-403', data = df_visualization_nominal)
print(df_visualization_nominal['CS-403'].value_counts())
# Out:
# 0     133
# 2     106
# 4      62
# 5      55
# 3      54
# 10     35
# 6      33
# 7      32
# 8      30
# 1      15
# 11     12
# 9       4
# Name: CS-403, dtype: int64

# %% [markdown]
# Here 0 is enocded value of a grade! And that is scored by 133 students for CS-403

# %%
ax = sns.countplot(x = 'CS-421', data = df_visualization_nominal)
print(df_visualization_nominal['CS-421'].value_counts())
# Out:
# 3     86
# 5     74
# 6     68
# 7     61
# 8     60
# 4     60
# 2     47
# 10    36
# 0     25
# 9     21
# 11    17
# 13    12
# 1      2
# 12     2
# Name: CS-421, dtype: int64

# %% [markdown]
# Here 3 is enocded value of a grade! And that is scored by 86 students for CS-421

# %%
ax = sns.countplot(x = 'CS-406', data = df_visualization_nominal)
print(df_visualization_nominal['CS-406'].value_counts())
# Out:
# 2     177
# 14     85
# 0      79
# 4      64
# 3      58
# 5      22
# 7      22
# 6      19
# 10     14
# 8       8
# 1       8
# 11      6
# 9       5
# 12      3
# 13      1
# Name: CS-406, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 177 students for CS-406

# %%
ax = sns.countplot(x = 'CS-414', data = df_visualization_nominal)
print(df_visualization_nominal['CS-414'].value_counts())
# Out:
# 0     176
# 2     156
# 4      62
# 3      54
# 5      21
# 1      21
# 7      21
# 6      20
# 13     13
# 8      12
# 11      7
# 10      3
# 9       3
# 12      2
# Name: CS-414, dtype: int64

# %% [markdown]
# Here 0 is enocded value of a grade! And that is scored by 176 students for CS-414

# %%
ax = sns.countplot(x = 'CS-419', data = df_visualization_nominal)
print(df_visualization_nominal['CS-419'].value_counts())
# Out:
# 2     120
# 3      89
# 4      85
# 5      78
# 0      56
# 7      46
# 6      40
# 8      20
# 12     13
# 10     13
# 9       7
# 1       2
# 11      2
# Name: CS-419, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 120 students for CS-419

# %%
ax = sns.countplot(x = 'CS-423', data = df_visualization_nominal)
print(df_visualization_nominal['CS-423'].value_counts())
# Out:
# 2     122
# 0      78
# 4      75
# 3      65
# 5      56
# 6      45
# 7      39
# 8      29
# 10     25
# 9      15
# 12     14
# 11      5
# 1       3
# Name: CS-423, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 122 students for CS-423

# %%
ax = sns.countplot(x = 'CS-412', data = df_visualization_nominal)
print(df_visualization_nominal['CS-412'].value_counts())
# Out:
# 2     157
# 4      80
# 13     79
# 0      77
# 3      65
# 5      37
# 7      24
# 6      19
# 10      8
# 8       7
# 11      6
# 9       5
# 1       4
# 12      3
# Name: CS-412, dtype: int64

# %% [markdown]
# Here 2 is enocded value of a grade! And that is scored by 157 students for CS-412

# %%
ax = sns.countplot(x = 'CGPA', data = df_visualization_nominal)
print(df_visualization_nominal['CGPA'].value_counts())
# Out:
# 243    5
# 256    3
# 195    3
# 363    3
# 73     3
#       ..
# 132    1
# 55     1
# 154    1
# 56     1
# 14     1
# Name: CGPA, Length: 491, dtype: int64

# %% [markdown]
# Here 243 is enocded value of a grade! And that is scored by 5 students for CGPA

# %%
# Satistical measures of my dataset...

df.describe()
# Out:
#          Seat No.      PH-121      HS-101      CY-105   HS-105/12      MT-111  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean   285.000000    3.781086    5.071804    2.921191    4.264448    3.935201
# std    164.977776    3.046895    2.785317    2.992228    3.216478    3.034481
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    142.500000    2.000000    3.000000    0.000000    2.000000    2.000000
# 50%    285.000000    3.000000    5.000000    2.000000    4.000000    4.000000
# 75%    427.500000    6.000000    7.000000    5.000000    7.000000    6.000000
# max    570.000000   12.000000   11.000000   13.000000   13.000000   13.000000
#
#            CS-105      CS-106      EL-102      EE-119  ...      CS-312  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.838879    4.161121    3.998249    3.921191  ...    4.299475
# ...

# %%
# it convert columns into row  and row into columns with transpose matrix...

df.describe().T
# Out:
#            count        mean         std  min    25%    50%    75%    max
# Seat No.   571.0  285.000000  164.977776  0.0  142.5  285.0  427.5  570.0
# PH-121     571.0    3.781086    3.046895  0.0    2.0    3.0    6.0   12.0
# HS-101     571.0    5.071804    2.785317  0.0    3.0    5.0    7.0   11.0
# CY-105     571.0    2.921191    2.992228  0.0    0.0    2.0    5.0   13.0
# HS-105/12  571.0    4.264448    3.216478  0.0    2.0    4.0    7.0   13.0
# MT-111     571.0    3.935201    3.034481  0.0    2.0    4.0    6.0   13.0
# CS-105     571.0    2.838879    2.696709  0.0    0.0    2.0    4.0   10.0
# CS-106     571.0    4.161121    2.774311  0.0    2.0    4.0    6.0   13.0
# EL-102     571.0    3.998249    3.075939  0.0    2.0    4.0    6.0   13.0
# EE-119     571.0    3.921191    2.698100  0.0    2.0    3.0    6.0   12.0
# ME-107     571.0    4.817863    3.179170  0.0    2.0    5.0    8.0   13.0
# CS-107     571.0    4.117338    3.304207  0.0    1.0    4.0    7.0   14.0
# ...

# %% [markdown]
# Correlation:

# %%
# correlation of the column with the target column...
df.corr()['CGPA'].sort_values()
# Out:
# CS-317      -0.800187
# EL-332      -0.792849
# CS-215      -0.778243
# CS-210      -0.770465
# CS-306      -0.769958
# CS-214      -0.769222
# CS-302      -0.751652
# CS-301      -0.746944
# MT-111      -0.744196
# MT-224      -0.733443
# CS-421      -0.729944
# CS-419      -0.710772
# MT-222      -0.691084
# CS-212      -0.687401
# TC-383      -0.680628
# CS-211      -0.678705
# ME-107      -0.676941
# CS-203      -0.676309
# EE-217      -0.671078
# EL-102      -0.654734
# EE-119      -0.653577
# CS-318      -0.651984
# CS-403      -0.645401
# PH-121      -0.644983
# CY-105      -0.644126
# MT-442      -0.635127
# CS-107      -0.632102
# HS-304      -0.629737
# HS-105/12   -0.623834
# EE-222      -0.620841
# CS-423      -0.606790
# MT-331      -0.594750
# CS-105      -0.587644
# EF-303      -0.570030
# CS-106      -0.551680
# CS-312      -0.544640
# HS-101      -0.541003
# HS-205/20   -0.473120
# CS-414      -0.452388
# CS-412      -0.449817
# CS-406      -0.244636
# ...

# %% [markdown]
# Checking the columns which are positive and negative correlated with the target columns

# %%
plt.figure(figsize = (22,7))
df.corr()['CGPA'].sort_values(ascending=False).drop('CGPA').plot(kind ='bar', color ='c')
plt.xlabel('Feature', fontsize=14)
plt.ylabel('column with target names', fontsize=14)
plt.title('correlation', fontsize=16)
plt.show()

# %% [markdown]
# Skewness:

# %% [markdown]
# Preprocessing od Dataset

# %% [markdown]
# Splitting the independent and target variable in x and y before removing the skewness:

# %%
x = df.drop(columns =['Seat No.', 'CGPA'], axis = 1)
y = df['CGPA']

# %%
x
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         5      10       8          6       8      10       9       8
# 1         0       9      10          9       5       6       9       0
# 2         0       3       0          5       4       0       5       4
# 3         9       7      10          9       9       2      10       8
# 4         2       2       2          4       0       0       2       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       3       0       0          2       1       0       2       2
# 567       1       0       0          0       0       0       0       2
# 568       3       0       2          4       0       0       0       0
# 569       0       4       9          0       9      10       5       8
# 570       6       9       9          6       6      10       3       7
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
y
# Out:
# 0       72
# 1       48
# 2      409
# 3       33
# 4      365
#       ...
# 566    459
# 567    457
# 568    369
# 569     70
# 570     14
# Name: CGPA, Length: 571, dtype: int64

# %%
df.skew()
# Out:
# Seat No.     0.000000
# PH-121       0.549104
# HS-101       0.053303
# CY-105       1.001752
# HS-105/12    0.337649
# MT-111       0.520916
# CS-105       0.930769
# CS-106       0.682923
# EL-102       0.532311
# EE-119       0.607213
# ME-107       0.131791
# CS-107       0.456184
# HS-205/20    1.155648
# MT-222       0.267531
# EE-222       0.864582
# MT-224       0.566537
# CS-210       0.966469
# CS-211       0.202623
# CS-203       0.337821
# CS-214       0.120394
# EE-217       0.876835
# CS-212       0.459739
# CS-215       0.288215
# MT-331       0.674150
# EF-303       0.547945
# HS-304       0.814333
# CS-301       0.489045
# CS-302       0.697409
# TC-383       0.379712
# MT-442       0.970582
# EL-332       0.587335
# CS-318       0.511718
# CS-306       0.575364
# CS-312       0.561465
# CS-317       0.273812
# CS-403       0.638689
# CS-421       0.317459
# CS-406       1.105583
# CS-414       1.592209
# CS-419       0.773674
# CS-423       0.627219
# ...

# %%
x.skew()
# Out:
# PH-121       0.549104
# HS-101       0.053303
# CY-105       1.001752
# HS-105/12    0.337649
# MT-111       0.520916
# CS-105       0.930769
# CS-106       0.682923
# EL-102       0.532311
# EE-119       0.607213
# ME-107       0.131791
# CS-107       0.456184
# HS-205/20    1.155648
# MT-222       0.267531
# EE-222       0.864582
# MT-224       0.566537
# CS-210       0.966469
# CS-211       0.202623
# CS-203       0.337821
# CS-214       0.120394
# EE-217       0.876835
# CS-212       0.459739
# CS-215       0.288215
# MT-331       0.674150
# EF-303       0.547945
# HS-304       0.814333
# CS-301       0.489045
# CS-302       0.697409
# TC-383       0.379712
# MT-442       0.970582
# EL-332       0.587335
# CS-318       0.511718
# CS-306       0.575364
# CS-312       0.561465
# CS-317       0.273812
# CS-403       0.638689
# CS-421       0.317459
# CS-406       1.105583
# CS-414       1.592209
# CS-419       0.773674
# CS-423       0.627219
# CS-412       1.086028
# ...

# %%
from sklearn.preprocessing import power_transform, PowerTransformer

# %%
pt = PowerTransformer()
x_new_pt = pt.fit_transform(x)
x_new_pt
# Out:
# array([[ 0.56128983,  1.67473424,  1.40996418, ...,  1.37542287,
#         -0.24376384, -0.49429154],
#        [-1.53065764,  1.35936594,  1.66690961, ...,  0.78542178,
#          0.68636321, -0.12983299],
#        [-1.53065764, -0.70688664, -1.27736731, ..., -1.94636503,
#         -0.63628208, -1.75640068],
#        ...,
#        [-0.04153262, -1.98470667,  0.0378983 , ...,  0.10380292,
#         -0.63628208, -0.49429154],
#        [-1.53065764, -0.33373024,  1.54462386, ..., -0.28856509,
#          0.4057714 ,  0.62339727],
#        [ 0.81556321,  1.35936594,  1.54462386, ...,  0.10380292,
#          1.4173958 ,  0.98170472]])

# %%
# numpy array...

x_new = power_transform(x)

# %%
x_new
# Out:
# array([[ 0.56128983,  1.67473424,  1.40996418, ...,  1.37542287,
#         -0.24376384, -0.49429154],
#        [-1.53065764,  1.35936594,  1.66690961, ...,  0.78542178,
#          0.68636321, -0.12983299],
#        [-1.53065764, -0.70688664, -1.27736731, ..., -1.94636503,
#         -0.63628208, -1.75640068],
#        ...,
#        [-0.04153262, -1.98470667,  0.0378983 , ...,  0.10380292,
#         -0.63628208, -0.49429154],
#        [-1.53065764, -0.33373024,  1.54462386, ..., -0.28856509,
#          0.4057714 ,  0.62339727],
#        [ 0.81556321,  1.35936594,  1.54462386, ...,  0.10380292,
#          1.4173958 ,  0.98170472]])

# %%
# Checking skewness...

pd.DataFrame(x_new, columns = x.columns).skew().sort_values(ascending = False)
# Out:
# CS-414       0.003274
# HS-304      -0.010235
# CS-406      -0.010247
# CY-105      -0.013385
# CS-419      -0.018974
# CS-412      -0.019138
# CS-106      -0.035471
# CS-105      -0.036751
# MT-442      -0.039984
# HS-205/20   -0.041345
# EF-303      -0.041603
# CS-421      -0.044662
# CS-210      -0.056488
# CS-212      -0.058932
# EE-217      -0.059222
# EE-119      -0.060215
# CS-318      -0.060450
# EE-222      -0.062081
# CS-302      -0.062379
# CS-423      -0.075842
# CS-306      -0.085208
# MT-331      -0.085933
# CS-301      -0.086933
# EL-332      -0.088548
# CS-317      -0.094418
# MT-224      -0.094988
# CS-312      -0.096983
# CS-403      -0.098391
# EL-102      -0.102588
# PH-121      -0.103905
# MT-111      -0.111260
# CS-107      -0.124000
# HS-101      -0.137673
# CS-203      -0.138451
# CS-215      -0.142590
# TC-383      -0.146982
# HS-105/12   -0.147028
# MT-222      -0.160588
# CS-214      -0.161104
# CS-211      -0.164417
# ME-107      -0.183446
# ...

# %%
x = pd.DataFrame(x_new, columns = x.columns)

# %%
# Validating the skewness has removed or not...

x.skew().sort_values(ascending = False)
# Out:
# CS-414       0.003274
# HS-304      -0.010235
# CS-406      -0.010247
# CY-105      -0.013385
# CS-419      -0.018974
# CS-412      -0.019138
# CS-106      -0.035471
# CS-105      -0.036751
# MT-442      -0.039984
# HS-205/20   -0.041345
# EF-303      -0.041603
# CS-421      -0.044662
# CS-210      -0.056488
# CS-212      -0.058932
# EE-217      -0.059222
# EE-119      -0.060215
# CS-318      -0.060450
# EE-222      -0.062081
# CS-302      -0.062379
# CS-423      -0.075842
# CS-306      -0.085208
# MT-331      -0.085933
# CS-301      -0.086933
# EL-332      -0.088548
# CS-317      -0.094418
# MT-224      -0.094988
# CS-312      -0.096983
# CS-403      -0.098391
# EL-102      -0.102588
# PH-121      -0.103905
# MT-111      -0.111260
# CS-107      -0.124000
# HS-101      -0.137673
# CS-203      -0.138451
# CS-215      -0.142590
# TC-383      -0.146982
# HS-105/12   -0.147028
# MT-222      -0.160588
# CS-214      -0.161104
# CS-211      -0.164417
# ME-107      -0.183446
# ...

# %%
sk = x.skew()

# %%
sk
# Out:
# PH-121      -0.103905
# HS-101      -0.137673
# CY-105      -0.013385
# HS-105/12   -0.147028
# MT-111      -0.111260
# CS-105      -0.036751
# CS-106      -0.035471
# EL-102      -0.102588
# EE-119      -0.060215
# ME-107      -0.183446
# CS-107      -0.124000
# HS-205/20   -0.041345
# MT-222      -0.160588
# EE-222      -0.062081
# MT-224      -0.094988
# CS-210      -0.056488
# CS-211      -0.164417
# CS-203      -0.138451
# CS-214      -0.161104
# EE-217      -0.059222
# CS-212      -0.058932
# CS-215      -0.142590
# MT-331      -0.085933
# EF-303      -0.041603
# HS-304      -0.010235
# CS-301      -0.086933
# CS-302      -0.062379
# TC-383      -0.146982
# MT-442      -0.039984
# EL-332      -0.088548
# CS-318      -0.060450
# CS-306      -0.085208
# CS-312      -0.096983
# CS-317      -0.094418
# CS-403      -0.098391
# CS-421      -0.044662
# CS-406      -0.010247
# CS-414       0.003274
# CS-419      -0.018974
# CS-423      -0.075842
# CS-412      -0.019138
# ...

# %%
sk.sort_values()
# Out:
# ME-107      -0.183446
# CS-211      -0.164417
# CS-214      -0.161104
# MT-222      -0.160588
# HS-105/12   -0.147028
# TC-383      -0.146982
# CS-215      -0.142590
# CS-203      -0.138451
# HS-101      -0.137673
# CS-107      -0.124000
# MT-111      -0.111260
# PH-121      -0.103905
# EL-102      -0.102588
# CS-403      -0.098391
# CS-312      -0.096983
# MT-224      -0.094988
# CS-317      -0.094418
# EL-332      -0.088548
# CS-301      -0.086933
# MT-331      -0.085933
# CS-306      -0.085208
# CS-423      -0.075842
# CS-302      -0.062379
# EE-222      -0.062081
# CS-318      -0.060450
# EE-119      -0.060215
# EE-217      -0.059222
# CS-212      -0.058932
# CS-210      -0.056488
# CS-421      -0.044662
# EF-303      -0.041603
# HS-205/20   -0.041345
# MT-442      -0.039984
# CS-105      -0.036751
# CS-106      -0.035471
# CS-412      -0.019138
# CS-419      -0.018974
# CY-105      -0.013385
# CS-406      -0.010247
# HS-304      -0.010235
# CS-414       0.003274
# ...

# %%
y.value_counts()
# Out:
# 243    5
# 256    3
# 195    3
# 363    3
# 73     3
#       ..
# 132    1
# 55     1
# 154    1
# 56     1
# 14     1
# Name: CGPA, Length: 491, dtype: int64

# %% [markdown]
# Oversampling the data:

# %% [markdown]
# Checking Outlier:

# %%
collist = df.columns.values
ncol = 20
nrows = 10
plt.figure(figsize = (ncol, 2*ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color = 'green', orient = 'v')
    plt.tight_layout()

# %% [markdown]
# Considering the outlier removal:

# %%
df.shape
# Out:
# (571, 43)

# %%
# Removing the Outlier:

from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(df))
threshold = 3
np.where(z>3)
# Out:
# (array([ 44,  44,  44,  44,  44,  44,  44,  44,  60,  60,  60,  60,  60,
#          60,  86,  91,  91,  91, 137, 137, 137, 137, 137, 137, 137, 142,
#         142, 142, 142, 142, 142, 143, 143, 143, 143, 143, 143, 143, 281,
#         281, 281, 281, 282, 282, 288, 288, 288, 288, 288, 288, 423, 424,
#         481, 543, 565, 565, 565, 565, 565, 565], dtype=int64),
#  array([ 3,  7, 12, 14, 16, 20, 25, 38,  3, 12, 14, 16, 25, 38, 38, 16, 25,
#         38,  3, 12, 14, 16, 20, 25, 38, 12, 14, 16, 20, 25, 38,  3, 12, 14,
#         16, 20, 25, 38,  7, 12, 25, 38, 25, 38, 12, 14, 16, 20, 25, 38, 38,
#         38, 38, 38, 12, 14, 16, 20, 25, 38], dtype=int64))

# %%
df_new_z = df[(z<3).all(axis = 1)]
df_new_z
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
df_new_z.shape
# Out:
# (556, 43)

# %% [markdown]
# Percentage of my Data Loss:

# %%
Data_loss = ((571-556)/571)*100

# %%
Data_loss
# Out:
# 2.626970227670753

# %% [markdown]
# Sperating the columns into features and Traget:

# %%
features = df.drop('CGPA',axis=1)
target = df['CGPA']

# %% [markdown]
# Train Model begin:

# %% [markdown]
# Scaling the Data Using Min-Max Scaller:

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range (0,100):
    features_train,features_test,target_train,target_test = train_test_split(features,target,test_size=0.2, random_state = i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i}, the training accuracy is:- {r2_score(target_train,pred_train)}")
    print(f"At random state {i}, the testing accuracy is:- {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0, the training accuracy is:- 0.9415528542751233
# At random state 0, the testing accuracy is:- 0.9396399888373139
#
#
# At random state 1, the training accuracy is:- 0.9403835435487813
# At random state 1, the testing accuracy is:- 0.9463143365450937
#
#
# At random state 2, the training accuracy is:- 0.9490386032635435
# At random state 2, the testing accuracy is:- 0.906791703033795
#
#
# At random state 3, the training accuracy is:- 0.9476839114457958
# At random state 3, the testing accuracy is:- 0.9208096975232014
#
#
# At random state 4, the training accuracy is:- 0.9385549344199691
# At random state 4, the testing accuracy is:- 0.9569075571450294
#
#
# At random state 5, the training accuracy is:- 0.94405728343704
# At random state 5, the testing accuracy is:- 0.9293520393133327
#
#
# At random state 6, the training accuracy is:- 0.9404955069013117
# At random state 6, the testing accuracy is:- 0.9498282401507877
#
#
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2, random_state=1)

# %%
# train the model:

lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.9463143365450937

# %% [markdown]
# Cross validation of the model:

# %%
Train_accuracy = r2_score(target_train,pred_train)
Test_accuracy = r2_score(target_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score = cross_val_score(lr,features,target,cv=j)
    cv_mean = cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for testing is {Test_accuracy}')
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.6696131249622433 and accuracy score for training is -0.9177117370688419 and accuracy for testing is 0.9463143365450937
#
#
# At cross fold 3 the cv score is 0.8826182775405028 and accuracy score for training is -0.9177117370688419 and accuracy for testing is 0.9463143365450937
#
#
# At cross fold 4 the cv score is 0.8936912152470935 and accuracy score for training is -0.9177117370688419 and accuracy for testing is 0.9463143365450937
#
#
# At cross fold 5 the cv score is 0.9166754269075064 and accuracy score for training is -0.9177117370688419 and accuracy for testing is 0.9463143365450937
#
#
# At cross fold 6 the cv score is 0.9185445150774855 and accuracy score for training is -0.9177117370688419 and accuracy for testing is 0.9463143365450937
#
#
# At cross fold 7 the cv score is 0.9199734360449571 and accuracy score for training is -0.9177117370688419 and accuracy for testing is 0.9463143365450937
#
#
# ...

# %% [markdown]
# Here we have handled the problem of the overfitting and underfitting by checking the training and testing score

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (6,4))
plt.scatter(x = target_test, y = pred_test, color = 'g')
plt.plot(target_test,target_test, color = 'b')
plt.xlabel('Actual charges', fontsize = 10)
plt.ylabel('Predicted charges' , fontsize = 10 )
plt.title('Linear Regression' , fontsize = 14)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# Regularization:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha' :[.0001, .001, .01, .1, 1,10],
              'random_state' : list(range(0,10))}

ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
# final model training...

ls = Lasso(alpha=10, random_state=0)
ls.fit(features_train,target_train)
ls_score_training = ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)
ls_score_training*100
# Out:
# 92.80830326105195

# %% [markdown]
# Ensemble Technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse','mae'],
              'max_features':['auto','sqrt','log2']}

rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train, target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
rf = RandomForestRegressor(criterion = 'mae', max_features = 'log2')
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test, pred_decision)
print('R2 score' , rfs*100)

rfscore = cross_val_score(rf,features,target,cv=5)
rfc = rfscore.mean()
print('cross_val_score', rfc*100)
# Out:
# R2 score 97.6583522724361
# cross_val_score 95.91145124645229

# %% [markdown]
# Now, we are getting model accuracy and cross validation :

# %%
import pickle
filename = 'Grades_of_student.pkl'
pickle.dump(rf,open(filename, 'wb'))

# %% [markdown]
# Conclusion:

# %%
loaded_model = pickle.load(open('Grades_of_student.pkl', 'rb'))
result = loaded_model.score(features_test, target_test)
print(result*100)
# Out:
# 97.6583522724361

# %%
conclusion = pd.DataFrame([loaded_model.predict(features_test)[:], pred_decision[:]], index = ['Predicted', 'Orginal'])

# %%
conclusion
# Out:
#                0       1      2       3       4        5        6       7    \
# Predicted  370.255  135.13  73.11  232.79  189.24  282.555  223.335  285.81
# Orginal    370.255  135.13  73.11  232.79  189.24  282.555  223.335  285.81
#
#               8      9    ...     105     106     107     108      109  \
# Predicted  284.58  49.54  ...  417.17  280.26  241.16  379.54  388.905
# Orginal    284.58  49.54  ...  417.17  280.26  241.16  379.54  388.905
#
#                110     111     112     113     114
# Predicted  468.595  215.65  185.29  117.05  228.81
# Orginal    468.595  215.65  185.29  117.05  228.81
#
# [2 rows x 115 columns]
