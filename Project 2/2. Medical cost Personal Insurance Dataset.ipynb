# %% [markdown]
# Medical Cost Personal insurance (Regression Algorithms)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset4/main/medical_cost_insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# About Columns..
#
# 1. Age :
#      it shows the age of the primary beneficiary of medical insurance cost
#
# 2. Sex :
#     it shows the patient of the sex i.e male and female which use the medical insurance.
#
# 3. BMI (Body Mass Index) :
#     it shows the body mass index of person. The BMI calculated by the height to weight ratio.
#
# 4. Childeren :
#     it shows number of children covered by  the medical insurance.
#
# 5. Smoker :
#     it shows the person ia a smoking.
#
# 6. Region :
#     it shows the beneficial resident area
#
# 7. Charges :
#     it shows individual medical cost billed by health insurance
#
#
#     the result is predict the accurate medical insurance cost

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %%
# np.nan,none,NaN,others ..... checking the null value-------

df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# checking the datatypes....

df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df_visualization_nominal=df[['age','sex','bmi','children','smoker','region','charges']].copy()

# %%
df_visualization_nominal.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# Visualization of Data :
#
# For the nominal categorical Data we will use countplot as it will we give the frequency of the classes of columns

# %%
import seaborn as sns

# %%
ax = sns.countplot(x = 'age', data = df_visualization_nominal)
print(df_visualization_nominal['age'].value_counts())
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
ax = sns.countplot(x = 'sex', data = df_visualization_nominal)
print(df_visualization_nominal['sex'].value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
ax = sns.countplot(x = 'bmi', data = df_visualization_nominal)
print(df_visualization_nominal['bmi'].value_counts())
# Out:
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64

# %%
ax = sns.countplot(x = 'children', data = df_visualization_nominal)
print(df_visualization_nominal['children'].value_counts())
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
ax = sns.countplot(x = 'smoker', data = df_visualization_nominal)
print(df_visualization_nominal['smoker'].value_counts())
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
ax = sns.countplot(x = 'region' , data = df_visualization_nominal)
print(df_visualization_nominal['region'].value_counts())
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
ax = sns.countplot(x = 'charges', data = df_visualization_nominal)
print(df_visualization_nominal['charges'].value_counts())
# Out:
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %% [markdown]
# Making DataFrame  of the ordinal Data:
#
# for the ordinal data we will use the lineplot or catplot as it will give the flow of the line of the classes of the columns.

# %%
df_visualiztion_ordinal=df[['age','sex','bmi', 'children', 'smoker', 'region', 'charges']].copy()

# %%
sns.catplot(x = 'age', y = 'charges' , data=df)

# %%
sns.catplot(x = 'sex', y= 'charges', data = df)

# %%
sns.catplot(x = 'bmi' , y = 'charges', data = df)

# %%
sns.catplot(x = 'children' , y = 'charges' , data = df)

# %%
sns.catplot(x = 'smoker', y = 'charges' , data = df)

# %%
sns.catplot(x = 'region' , y= 'charges', data = df)

# %% [markdown]
# Checking the distribution of the continues value of the float type columns

# %%
df_visualization_continues=df[['bmi', 'charges']].copy()

# %%
sns.displot(df_visualization_continues['charges'], kde=True)

# %%
sns.displot(df_visualization_continues['bmi'], kde=True)

# %% [markdown]
# Visualization Part is completed

# %% [markdown]
# Since the dataset has a lot of string value, we will use encoding technique to convert the string data to numerical one

# %% [markdown]
# Encoding Technique

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]= enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  0.0  27.900         0     1.0     3.0  16884.92400
# 1      18  1.0  33.770         1     0.0     2.0   1725.55230
# 2      28  1.0  33.000         3     0.0     2.0   4449.46200
# 3      33  1.0  22.705         0     0.0     1.0  21984.47061
# 4      32  1.0  28.880         0     0.0     1.0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  1.0  30.970         3     0.0     1.0  10600.54830
# 1334   18  0.0  31.920         0     0.0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0     2.0   1629.83350
# 1336   21  0.0  25.800         0     0.0     3.0   2007.94500
# 1337   61  0.0  29.070         0     1.0     1.0  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Describe the dataset

# %%
# only continues coulumns...

df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.515695  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (22,7))
sns.heatmap(df.describe(), annot=True, linewidth=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Correlation

# %%
df.corr()['charges'].sort_values()
# Out:
# region     -0.006208
# sex         0.057292
# children    0.067998
# bmi         0.198341
# age         0.299008
# smoker      0.787251
# charges     1.000000
# Name: charges, dtype: float64

# %%
plt.figure(figsize = (22,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.1, linecolor='black', fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Correlation outcomes :
#
# At the columns of Dataset is positive correlated with the target columns.
#
# Age has 30 percent correlation with the target column which can be considered good bond. Sex has 6 percent correlation with
# the target column which can be considered weak bond. BMI has 20 percent correlation with the target column which can be
# considered good bond. Children has 7 percent correlation with the target column which can be considered weak bond. Smoker has
# 79 percent correlation with the target column which can be considered strong bond.Region -1 percent correlation with the target
# column which can considered with the negative bond.

# %% [markdown]
# Checking the columns which are positive and negative correlated with the target columns

# %%
plt.figure(figsize = (22,7))
df.corr()['charges'].sort_values(ascending=False).drop('charges').plot(kind ='bar', color ='c')
plt.xlabel('Feature', fontsize=14)
plt.ylabel('column with target names', fontsize=14)
plt.title('correlation', fontsize=16)
plt.show()

# %% [markdown]
# Skewness:
#
# The Skewness is shifted to one side either right side or left side.

# %%
df.skew()
# Out:
# age         0.055673
# sex        -0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.038101
# charges     1.515880
# dtype: float64

# %% [markdown]
# Outliers Check

# %%
df.dtypes
# Out:
# age           int64
# sex         float64
# bmi         float64
# children      int64
# smoker      float64
# region      float64
# charges     float64
# dtype: object

# %% [markdown]
# Checking the outliers on the int and float type of columns

# %%
df['age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['sex'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['bmi'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['children'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['smoker'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['region'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Considered the outliers removal:

# %%
df.shape
# Out:
# (1338, 7)

# %%
from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(df))
threshold = 3
np.where(z>3)
# Out:
# (array([  32,   34,   71,  116,  166,  413,  425,  438,  543,  568,  577,
#          640,  819,  847,  877,  932,  937,  969,  984, 1047, 1085, 1116,
#         1130, 1146, 1230, 1245, 1272, 1300, 1317], dtype=int64),
#  array([3, 6, 3, 2, 3, 3, 3, 3, 6, 3, 6, 3, 6, 2, 3, 3, 3, 3, 3, 2, 3, 3,
#         3, 6, 6, 3, 3, 6, 2], dtype=int64))

# %%
import numpy as np

# %%
df_new_z = df[(z<3).all(axis=1)]
df_new_z
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19  0.0  27.900         0     1.0     3.0  16884.92400
# 1      18  1.0  33.770         1     0.0     2.0   1725.55230
# 2      28  1.0  33.000         3     0.0     2.0   4449.46200
# 3      33  1.0  22.705         0     0.0     1.0  21984.47061
# 4      32  1.0  28.880         0     0.0     1.0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50  1.0  30.970         3     0.0     1.0  10600.54830
# 1334   18  0.0  31.920         0     0.0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0     2.0   1629.83350
# 1336   21  0.0  25.800         0     0.0     3.0   2007.94500
# 1337   61  0.0  29.070         0     1.0     1.0  29141.36030
#
# [1309 rows x 7 columns]

# %%
df_new_z.shape
# Out:
# (1309, 7)

# %% [markdown]
# Percentage of Data loss:

# %%
Data_loss = ((1338-1309)/1338)*100

# %%
Data_loss
# Out:
# 2.167414050822123

# %% [markdown]
# Seprating the columns features and Target:

# %%
features = df.drop('charges', axis = 1)
target = df['charges']

# %% [markdown]
# Scaling the data using Min-Mix Scaler:

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test = train_test_split(features,target,test_size = 0.2 , random_state = i)
    lr.fit(features_train,target_train)
    pred_train = lr.predict(features_train)
    pred_test = lr.predict(features_test)
    print(f'At random state {i}, the training accuracy is :- {r2_score(target_train,pred_train)}')
    print(f'At random state {i}, the training accuracy is :- {r2_score(target_test,pred_test)}')
    print("\n")
# Out:
# At random state 0, the training accuracy is :- 0.7368306228430945
# At random state 0, the training accuracy is :- 0.7998747145449959
#
#
# At random state 1, the training accuracy is :- 0.7475615631933097
# At random state 1, the training accuracy is :- 0.7623224022563388
#
#
# At random state 2, the training accuracy is :- 0.7519923667088932
# At random state 2, the training accuracy is :- 0.7445422986536503
#
#
# At random state 3, the training accuracy is :- 0.7530732192579027
# At random state 3, the training accuracy is :- 0.7406256738597918
#
#
# At random state 4, the training accuracy is :- 0.7605730367332922
# At random state 4, the training accuracy is :- 0.6970099489172213
#
#
# At random state 5, the training accuracy is :- 0.742751800397326
# At random state 5, the training accuracy is :- 0.7790865933969187
#
#
# At random state 6, the training accuracy is :- 0.7433828393740967
# At random state 6, the training accuracy is :- 0.7785295914318422
#
#
# ...

# %%
features_train,features_test,target_train,target_test = train_test_split(features,target,test_size = 0.2 , random_state = 12)

# %%
# train the model...

lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.7096380405273459

# %% [markdown]
# Cross Validation of the model:

# %%
Train_accuracy = r2_score(target_train, pred_train)
Test_accuracy = r2_score(target_train, pred_train)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score = cross_val_score(lr,features,target,cv=j)
    cv_mean = cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for testing is {Test_accuracy}')
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.7486033254037108 and accuracy score for training is -0.6506986173795262 and accuracy for testing is -0.6506986173795262
#
#
# At cross fold 3 the cv score is 0.7448455049684157 and accuracy score for training is -0.6506986173795262 and accuracy for testing is -0.6506986173795262
#
#
# At cross fold 4 the cv score is 0.7465374465214437 and accuracy score for training is -0.6506986173795262 and accuracy for testing is -0.6506986173795262
#
#
# At cross fold 5 the cv score is 0.7472559473580954 and accuracy score for training is -0.6506986173795262 and accuracy for testing is -0.6506986173795262
#
#
# At cross fold 6 the cv score is 0.7458863313669323 and accuracy score for training is -0.6506986173795262 and accuracy for testing is -0.6506986173795262
#
#
# At cross fold 7 the cv score is 0.7452991860582022 and accuracy score for training is -0.6506986173795262 and accuracy for testing is -0.6506986173795262
#
#
# ...

# %% [markdown]
# Here we have handled the problem of the overfitting and underfitting by checking the training and testing score

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (6,4))
plt.scatter(x = target_test, y = pred_test, color = 'g')
plt.plot(target_test,target_test, color = 'b')
plt.xlabel('Actual charges', fontsize = 12)
plt.ylabel('Predicted charges' , fontsize = 12 )
plt.title('Linear Regression' , fontsize = 16)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# Regularization :

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha' :[.0001, .001, .01, .1, 1,10],
              'random_state' : list(range(0,10))}

ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
# final model training...

ls = Lasso(alpha=10, random_state=0)
ls.fit(features_train,target_train)
ls_score_training = ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)
ls_score_training*100
# Out:
# 76.04177389512891

# %% [markdown]
# Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse','mae'],
              'max_features':['auto','sqrt','log2']}

rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train, target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
rf = RandomForestRegressor(criterion = 'mae', max_features = 'log2')
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test, pred_decision)
print('R2 score' , rfs*100)

rfscore = cross_val_score(rf,features,target,cv=5)
rfc = rfscore.mean()
print('cross_val_score', rfc*100)
# Out:
# R2 score 81.9419366871821
# cross_val_score 84.29059417088067

# %% [markdown]
# Now, we are getting model accuracy and cross validation :

# %%
import pickle
filename = 'Medical_insurance_cost.pkl'
pickle.dump(rf,open(filename, 'wb'))

# %% [markdown]
# Conclusion:

# %%
loaded_model = pickle.load(open('Medical_insurance_cost.pkl', 'rb'))
result = loaded_model.score(features_test, target_test)
print(result*100)
# Out:
# 81.9419366871821

# %%
conclusion = pd.DataFrame([loaded_model.predict(features_test)[:], pred_decision[:]], index = ['Predicted', 'Orginal'])

# %%
conclusion
# Out:
#                    0            1             2            3            4    \
# Predicted  9231.663053  3447.304561  21295.036634  9503.499217  2379.619207
# Orginal    9231.663053  3447.304561  21295.036634  9503.499217  2379.619207
#
#                    5            6             7            8             9    \
# Predicted  3630.232543  4632.671478  13606.787475  6950.554283  37506.967949
# Orginal    3630.232543  4632.671478  13606.787475  6950.554283  37506.967949
#
#            ...          258           259          260           261  \
# Predicted  ...  4948.726164  41015.973551  13616.54712  12889.032584
# Orginal    ...  4948.726164  41015.973551  13616.54712  12889.032584
#
#                    262           263          264           265           266  \
# Predicted  6887.012336  24459.454157  5270.217979  13177.860993  13873.157233
# Orginal    6887.012336  24459.454157  5270.217979  13177.860993  13873.157233
#
#                    267
# Predicted  13846.55045
# ...
