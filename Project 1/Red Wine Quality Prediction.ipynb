# %% [markdown]
# Red Wine quality Pridiction (Classification task)

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Checking the Null Value......
# np.nan, none, NaN , other

df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# EDA - Expolatory Data Analysis

# %% [markdown]
# Scatterplot -- bcz it use to find out the relationship..

# %%
import seaborn as sns
sns.scatterplot(x = 'fixed acidity' , y = 'quality' , data = df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(x = 'volatile acidity', y='quality', data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
sns.scatterplot(x = 'citric acid' , y='quality' ,data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
sns.scatterplot(x = 'residual sugar',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(x='chlorides',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
sns.scatterplot(x='free sulfur dioxide', y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x='total sulfur dioxide', y='quality', data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x='density',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
sns.scatterplot(x='pH', y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.scatterplot(x='sulphates', y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
sns.scatterplot(x='alcohol', y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %% [markdown]
# Correlation -- it find out the relationship b/w the variable.

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# Correlation using heatmap

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True, linewidths=0.5, linecolor='black', fmt = '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outcome of Correlation:
#
# At the columns of the dataset is positively correlated with the target column.
#
# Fixed acidity has 12 percent correlation with the target column  which can be considered week bond.Volatile acidity has
# -39 percent correlation with the target column which can considered negetive bond. Citric acid has 23 percent correlation with
# the target column which can considered good bond . Residual Sugar has 1 percent correlation with the target column which can
# considered Week bond. Chorides has -13 percent correlation with the target column which can considered negative bond. Free
# sulphur dioxide has -5 percent correlation with the target column which can considered negative bond. Total sulphur dioxide has
# -19 percent  correlation wit the target column which can considered negative bond. Density has -17 percent correlation with the
# target column which can considered negative bond. PH has -6 percent correlation with the target column which can considered
# negative bond. sulphates has 25 percent correlation with the target column which can considered good bond. Alcohol has 48
# percent correlation with the target column which can considered Strong bond.

# %%
# Describe Dataset...

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables summary")
plt.show()

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Checking Outliers

# %%
collist=df.columns.values
ncol=30
nrows=20
plt.figure(figsize=(ncol,3*ncol))
for i in range(0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green', orient='v')
    plt.tight_layout()

# %% [markdown]
# Skewness:
#
# The Skewness is shifted to one side either left or right side.

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# Outcome of skewness: Skewness threshold is taken is +/-0.65. Columns which are having skewness.

# %% [markdown]
# Normal Distribution curve:

# %%
sns.displot(df['fixed acidity'])

# %%
sns.displot(df['volatile acidity'])

# %%
sns.displot(df['citric acid'])

# %%
sns.displot(df['residual sugar'])

# %%
sns.displot(df['chlorides'])

# %%
sns.displot(df['free sulfur dioxide'])

# %%
sns.displot(df['total sulfur dioxide'])

# %%
sns.displot(df['density'])

# %%
sns.displot(df['pH'])

# %%
sns.displot(df['sulphates'])

# %%
sns.displot(df['alcohol'])

# %% [markdown]
# The normal distribution bar outcomes is irrelevant
#
# the normal distribution shows that data is Skewed

# %% [markdown]
# Data Cleaning:

# %%
delete=pd.DataFrame([['-0.050656','free sulfur dioxide','No','Alot'],['-0.057731', 'pH', 'No', 'Alot']],columns=['Correlation with Target','Column Name', 'Normalised','Outliers'])
delete
# Out:
#   Correlation with Target          Column Name Normalised Outliers
# 0               -0.050656  free sulfur dioxide         No     Alot
# 1               -0.057731                   pH         No     Alot

# %% [markdown]
# Here, We are setting threshold of correlation as +/-0.1. It is not satandard. The dataset demands.

# %%
df=df.drop(['free sulfur dioxide','pH'],axis=1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 10)

# %% [markdown]
# Removing Outliers:

# %% [markdown]
# Z-Score Technique:

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(x))
z.shape
# Out:
# (1599, 9)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   15,   17,   17,   19,   33,   38,   42,   43,   81,   81,
#          83,   86,   88,   91,   92,  106,  106,  109,  120,  126,  127,
#         142,  144,  147,  151,  151,  151,  163,  164,  169,  169,  181,
#         199,  226,  226,  240,  243,  244,  258,  258,  274,  281,  291,
#         324,  325,  339,  340,  347,  354,  374,  381,  391,  396,  400,
#         442,  442,  451,  467,  480,  480,  494,  515,  544,  554,  554,
#         555,  555,  557,  557,  568,  588,  591,  595,  608,  614,  636,
#         639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#         692,  692,  723,  724,  730,  754,  776,  777,  795,  821,  836,
#         837,  889,  911,  917,  923, 1017, 1018, 1043, 1051, 1051, 1071,
#        1074, 1079, 1079, 1081, 1081, 1114, 1165, 1186, 1235, 1244, 1244,
#        1260, 1269, 1269, 1270, 1270, 1288, 1289, 1299, 1312, 1319, 1319,
#        1367, 1370, 1370, 1372, 1372, 1374, 1434, 1434, 1435, 1435, 1474,
# ...

# %%
x=x[(z<3).all(axis=1)]
print(df.shape)
print(x.shape)
#x.shape
# Out:
# (1599, 10)
# (1478, 9)

# %%
x.shape
# Out:
# (1478, 9)

# %%
y=y[(z<3).all(axis=1)]
y.shape
# Out:
# (1478,)

# %% [markdown]
# Percentage data loss:

# %%
loss_percent=(1599-1478)/1599*100
print(loss_percent)
# Out:
# 7.5672295184490315

# %% [markdown]
# Checking whether how much outliers are still there help in the testing the model or not

# %% [markdown]
# Model without outliers is df and model with desired outliers is df_new1:

# %% [markdown]
# Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.45329452,  1.04349172, -1.51381571, ...,  0.63914437,
#         -0.58833616, -1.11417576],
#        [-0.16479907,  1.90684496, -1.51381571, ...,  0.06417446,
#          0.45088848, -0.53226443],
#        [-0.16479907,  1.34433512, -1.23341414, ...,  0.17950238,
#          0.21969274, -0.53226443],
#        ...,
#        [-1.39357638, -0.01130981, -0.65280575, ..., -0.54986596,
#          0.92935402,  0.73069322],
#        [-1.80264919,  0.75498738, -0.71417098, ..., -0.70702896,
#          0.66578119, -0.04141271],
#        [-1.69639392, -1.33239623,  1.0778912 , ..., -0.69537669,
#          0.29866266,  0.73069322]])

# %% [markdown]
# Scalling the data using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
x
# Out:
# array([[-0.45329452,  1.04349172, -1.51381571, ...,  0.63914437,
#         -0.58833616, -1.11417576],
#        [-0.16479907,  1.90684496, -1.51381571, ...,  0.06417446,
#          0.45088848, -0.53226443],
#        [-0.16479907,  1.34433512, -1.23341414, ...,  0.17950238,
#          0.21969274, -0.53226443],
#        ...,
#        [-1.39357638, -0.01130981, -0.65280575, ..., -0.54986596,
#          0.92935402,  0.73069322],
#        [-1.80264919,  0.75498738, -0.71417098, ..., -0.70702896,
#          0.66578119, -0.04141271],
#        [-1.69639392, -1.33239623,  1.0778912 , ..., -0.69537669,
#          0.29866266,  0.73069322]])

# %%
y.value_counts()
# Out:
# 5    624
# 6    595
# 7    188
# 4     48
# 8     16
# 3      7
# Name: quality, dtype: int64

# %%
# !pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Oversampling the data...

from imblearn.over_sampling import SMOTE
SM = SMOTE()
x,y = SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 5    624
# 6    624
# 7    624
# 4    624
# 8    624
# 3    624
# Name: quality, dtype: int64

# %% [markdown]
# Since the outcome has only two or more variable we will use binary classification model
#
# Use Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score

# %% [markdown]
# Splitting the DataFrame

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = i,test_size = 0.20)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr. predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state",i,"The model performs very well")
        print('At random state:-',i)
        print('Training accuracy is:-',accuracy_score(y_train,pred_train)*100)
        print('Testing accuracy is:-',accuracy_score(y_test,pred_test)*100)
# Out:
# At random state 45 The model performs very well
# At random state:- 45
# Training accuracy is:- 56.89482470784641
# Testing accuracy is:- 56.87583444592791
# At random state 47 The model performs very well
# At random state:- 47
# Training accuracy is:- 56.227045075125204
# Testing accuracy is:- 56.2082777036048
# At random state 58 The model performs very well
# At random state:- 58
# Training accuracy is:- 56.72787979966611
# Testing accuracy is:- 56.742323097463284
# At random state 160 The model performs very well
# At random state:- 160
# Training accuracy is:- 56.89482470784641
# Testing accuracy is:- 56.87583444592791
# At random state 266 The model performs very well
# At random state:- 266
# Training accuracy is:- 56.594323873121866
# Testing accuracy is:- 56.60881174899867
# At random state 286 The model performs very well
# At random state:- 286
# Training accuracy is:- 57.29549248747913
# Testing accuracy is:- 57.27636849132176
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state = 899)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.20      0.24      0.22       115
#            4       0.22      0.17      0.20       143
#            5       0.12      0.13      0.13       121
#            6       0.21      0.18      0.20       130
#            7       0.14      0.15      0.14       107
#            8       0.16      0.17      0.17       133
#
#     accuracy                           0.18       749
#    macro avg       0.18      0.18      0.18       749
# weighted avg       0.18      0.18      0.18       749

# %% [markdown]
# Cross Validation score for logistic regression:

# %%
pred_lr = lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss = accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore = cross_val_score(lr,x,y,cv=j)
    lsc = lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("accuarcy_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 52.83119658119658
# accuarcy_score is:- 56.074766355140184
#
#
# At cv:- 3
# Cross validation score is:- 53.31196581196581
# accuarcy_score is:- 56.074766355140184
#
#
# At cv:- 4
# Cross validation score is:- 53.979700854700866
# accuarcy_score is:- 56.074766355140184
#
#
# At cv:- 5
# Cross validation score is:- 54.05945895775473
# accuarcy_score is:- 56.074766355140184
#
#
# At cv:- 6
# Cross validation score is:- 54.27350427350428
# accuarcy_score is:- 56.074766355140184
#
#
# At cv:- 7
# Cross validation score is:- 54.406574558837505
# accuarcy_score is:- 56.074766355140184
#
#
# At cv:- 8
# Cross validation score is:- 54.994658119658126
# accuarcy_score is:- 56.074766355140184
#
#
# At cv:- 9
# Cross validation score is:- 55.44871794871795
# accuarcy_score is:- 56.074766355140184

# %% [markdown]
# Since cross validation score accuracy score are almost same. We are heading with a good approach.

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=4).mean()
print("The cv score is:-",lsscore_selected,"\nThe accuracy score is:",lss)
# Out:
# The cv score is:- 0.5397970085470086
# The accuracy score is: 0.5607476635514018

# %%
# Checking accuracy for Random Forest Classifier..

from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.87716955941255
# [[115   0   0   0   0   0]
#  [  1 135   6   1   0   0]
#  [  2   5  91  19   4   0]
#  [  0   4  24  84  16   2]
#  [  0   0   3   3  99   2]
#  [  0   0   0   0   0 133]]
#               precision    recall  f1-score   support
#
#            3       0.97      1.00      0.99       115
#            4       0.94      0.94      0.94       143
#            5       0.73      0.75      0.74       121
#            6       0.79      0.65      0.71       130
#            7       0.83      0.93      0.88       107
#            8       0.97      1.00      0.99       133
#
#     accuracy                           0.88       749
#    macro avg       0.87      0.88      0.87       749
# weighted avg       0.87      0.88      0.87       749

# %%
# Checking CV score for Random Forest Classifier..

score = cross_val_score(RFC,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy and cross validation score is:-", accuracy_score(y_test,predRFC) - score.mean())
# Out:
# [0.80774366 0.79572764 0.80907877 0.81441923 0.82486631]
# 0.8103671205100562
# Difference between Accuracy and cross validation score is:- 0.06680243890249382

# %%
# Checking accuracy for Support vector Classifier

from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train, y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test, predsvc))
print(confusion_matrix(y_test, predsvc))
print(classification_report(y_test, predsvc))
# Out:
# 0.7837116154873164
# [[115   0   0   0   0   0]
#  [  4 128   6   4   1   0]
#  [  1  20  71  23   5   1]
#  [  3  17  25  58  21   6]
#  [  0   2   7  10  82   6]
#  [  0   0   0   0   0 133]]
#               precision    recall  f1-score   support
#
#            3       0.93      1.00      0.97       115
#            4       0.77      0.90      0.83       143
#            5       0.65      0.59      0.62       121
#            6       0.61      0.45      0.52       130
#            7       0.75      0.77      0.76       107
#            8       0.91      1.00      0.95       133
#
#     accuracy                           0.78       749
#    macro avg       0.77      0.78      0.77       749
# weighted avg       0.77      0.78      0.77       749

# %%
# Checking cv score for Support Vector Machine Classifier

score = cross_val_score(svc,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and Cross validation score:-", accuracy_score(y_test,predsvc) - score.mean())
# Out:
# [0.76368491 0.73698264 0.71962617 0.75433912 0.7486631 ]
# 0.7446591890792
# Difference between Accuracy score and Cross validation score:- 0.03905242640811635

# %%
# Checking accuracy for Gradient Boosting Classifier..

GB = GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB = GB.predict(x_test)
print(accuracy_score(y_test, predGB))
print(confusion_matrix(y_test, predGB))
print(classification_report(y_test, predGB))
# Out:
# 0.8117489986648865
# [[115   0   0   0   0   0]
#  [  3 129   7   4   0   0]
#  [  5   7  83  23   3   0]
#  [  2   9  27  67  22   3]
#  [  1   0   3  17  81   5]
#  [  0   0   0   0   0 133]]
#               precision    recall  f1-score   support
#
#            3       0.91      1.00      0.95       115
#            4       0.89      0.90      0.90       143
#            5       0.69      0.69      0.69       121
#            6       0.60      0.52      0.56       130
#            7       0.76      0.76      0.76       107
#            8       0.94      1.00      0.97       133
#
#     accuracy                           0.81       749
#    macro avg       0.80      0.81      0.80       749
# weighted avg       0.80      0.81      0.81       749

# %%
# Checking CV Score for Gradient Boosting Classifier..

score = cross_val_score(GB,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and Cross validation score:-", accuracy_score(y_test, predGB) - score.mean())
# Out:
# [0.79305741 0.77169559 0.78371162 0.78504673 0.77139037]
# 0.7809803445592342
# Difference between Accuracy score and Cross validation score:- 0.030768654105652327

# %%
# Checking accuracy for Extra Trees Classifier...

ET = ExtraTreesClassifier()
ET.fit(x_train, y_train)
predET = ET.predict(x_test)
print(accuracy_score(y_test, predET))
print(confusion_matrix(y_test, predET))
print(classification_report(y_test, predET))
# Out:
# 0.8825100133511349
# [[115   0   0   0   0   0]
#  [  0 136   6   1   0   0]
#  [  3   8  89  19   2   0]
#  [  0   5  20  88  15   2]
#  [  0   0   2   5 100   0]
#  [  0   0   0   0   0 133]]
#               precision    recall  f1-score   support
#
#            3       0.97      1.00      0.99       115
#            4       0.91      0.95      0.93       143
#            5       0.76      0.74      0.75       121
#            6       0.78      0.68      0.72       130
#            7       0.85      0.93      0.89       107
#            8       0.99      1.00      0.99       133
#
#     accuracy                           0.88       749
#    macro avg       0.88      0.88      0.88       749
# weighted avg       0.88      0.88      0.88       749

# %%
# Checking CV score for Extra Trees Classifier...

score = cross_val_score(ET,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and Cross validation score:-", accuracy_score(y_test, predET) - score.mean())
# Out:
# [0.82242991 0.83044059 0.82376502 0.83311081 0.83823529]
# 0.8295963245111129
# Difference between Accuracy score and Cross validation score:- 0.05291368884002201

# %% [markdown]
# Hyper Parameter Tuning:

# %%
# ExtraTrees Classifier...

from sklearn.model_selection import GridSearchCV

parameters = {'criterion' : ['gini', 'entropy'],
              'random_state' : [10,50,1000],
              'max_depth' : [0,10,20],
              'n_jobs' : [-2,-1,1],
              'n_estimators' : [50,100,200,300]}

# %%
GCV = GridSearchCV(ExtraTreesClassifier(), parameters, cv = 5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [50, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1000]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'n_estimators': 200,
#  'n_jobs': -2,
#  'random_state': 1000}

# %%
final_model = ExtraTreesClassifier(criterion = 'gini', max_depth = 20, n_estimators = 300, n_jobs = -2, random_state = 10)
final_model.fit(x_train,y_train)
pred = final_model.predict(x_train)
acc = accuracy_score(y_train, pred)
print(acc*100)
# Out:
# 100.0

# %% [markdown]
# Model Saving :

# %%
import pickle
filename = 'Red_Wine.pkl'
pickle.dump(lr, open(filename, 'wb'))

# %% [markdown]
# Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com= pd.DataFrame({'original': a, 'predicted': predicted}, index=range(len(a)))
